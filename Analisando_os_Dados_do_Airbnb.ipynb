# %% [markdown]
# <a href="https://colab.research.google.com/github/robson-ribeiro-da-silva/projects_data_science/blob/main/Analisando_os_Dados_do_Airbnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ESTUDO DE CASO COM DATA SCIENCE**
#
#
# **<img alt="Logo" width="50%"  height="80" src="https://raw.githubusercontent.com/robson-ribeiro-da-silva/imagens/06b7c1b7ad2430cc21bd537aa63295410b1fddaa/banner_data_science_.jpg">**
#
#
# ##### Curso: **Data Science na Prática 2.0** *by [sigmoidal.ai](https://sigmoidal.ai)*  -  <img alt="Colaboratory logo" width="8%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
#
#
# ---
#
# # Análise dos Dados do Airbnb - **_Vancouver_, Canadá**
#
# O [Airbnb](https://www.airbnb.com.br/) já é considerado como sendo a **maior empresa hoteleira da atualidade**. Ah, o detalhe é que ele **não possui nenhum hotel**!
#
# Conectando pessoas que querem viajar (e se hospedar) com anfitriões que querem alugar seus imóveis de maneira prática, o Airbnb fornece uma plataforma inovadora para tornar essa hospedagem alternativa.
#
# No final de 2018, a Startup fundada 10 anos atrás, já havia **hospedado mais de 300 milhões** de pessoas ao redor de todo o mundo, desafiando as redes hoteleiras tradicionais.
#
# Uma das iniciativas do Airbnb é disponibilizar dados do site, para algumas das principais cidades do mundo. Por meio do portal [Inside Airbnb](http://insideairbnb.com/get-the-data.html), é possível baixar uma grande quantidade de dados para desenvolver projetos e soluções de *Data Science*.
#
# **<img alt="Analisando Airbnb" width="12%" src="https://www.area360.com.au/wp-content/uploads/2017/09/airbnb-logo.jpg">**
#
# **Neste *notebook*, iremos analisar os dados referentes à cidade de _Vancouver_, e ver quais insights podem ser extraídos a partir de dados brutos.**
#
# _Análise realizada em 30/03/2021_
#
#
# ---

# %% [markdown]
# ## **Vancouver**
#
# **A terceira maior cidade e um dos maiores centros culturais e comerciais do Canadá**, Vancouver é caracterizada por sua beleza natural única que se adaptou ao constante desenvolvimento.
#
# Rodeada pelo _Oceano Pacífico_ e por _montanhas nevadas_, Vancouver é a maior área metropolitana no oeste do Canadá e está entre as **cidades mais bonitas do país** pelo seu contraste entre as residências vitorianas, os modernos arranha-céus e a maravilhosa natureza.
#
# <img alt="Paisagem Vancouver" src="https://raw.githubusercontent.com/robson-ribeiro-da-silva/imagens/eb6d1f7539ae4530fe83cdab30b59e78413b8d92/Place_Vancouver.jpg">
#
# _Possuindo um clima que costuma agradar aos anfitriões, no verão a temperatura média é de 20 graus com uma variação que pode chegar acima dos 30 graus em alguns periodos e no inverno raramente chega abaixo de zero grau_.
#
# A bela paisagem natural em torno da cidade, os muitos parques, as praias, além de outros locais de recreação, fazem de Vancouver um dos principais destinos turísticos e uma das melhores cidades do mundo para se viver. **A cidade foi considerada em 2001 pela ONU a melhor cidade do mundo em qualidade de vida**.
#
# Atraindo mais de um milhão de pessoas por ano em férias de cruzeiro Vancouver é uma cidade que vive basicamente do turismo, com centenas de parques, praias, lagos e montanhas, sem contar com os vários prédios famosos e com algumas construções em estilo europeu. **São mais de 153 pontos turístico**.
#
#
# <img alt="Cidade Vancouver" width="800%"  height="150" src="https://raw.githubusercontent.com/robson-ribeiro-da-silva/imagens/3e8020def226f13afb15a8e898b4bcf6058062b5/img_vancouver_science_world.jpg">
#
# ---

# %% [markdown]
# ## Obtenção dos Dados
#
# Todos os dados usados aqui foram obtidos a partir do site [Inside Airbnb](http://insideairbnb.com/get-the-data.html).
#
# Para esta análise exploratória inicial, será baixado apenas o seguinte arquivo que contém informações resumidas sobre as listagens dos imóveis em Vancouver:
#
# * `listings.csv` - *Summary information and metrics for listings in Vancouver  (good for visualisations).*

# %% [markdown]
# #### Bibliotecas e Pacotes utilizados
#
# * `pandas` - é uma biblioteca de código aberto que fornece estruturas de dados de alto desempenho e fáceis de usar e ferramentas de análise de dados para a linguagem de programação Python. [Documentação](https://pandas.pydata.org/docs/)
# * `matplotlib` - é uma biblioteca abrangente para a criação de visualizações estáticas, animadas e interativas em Python. [Documentação](https://matplotlib.org/3.3.3/index.html)
# * `seaborn` - é uma biblioteca de visualização de dados Python baseada em  [matplotlib](https://matplotlib.org/3.3.3/index.html). Ele fornece uma interface de alto nível para desenhar gráficos estatísticos atraentes e informativos. [Documentação](https://seaborn.pydata.org/)
# * `plotly.express` - é uma API concisa, consistente e de alto nível para a criação de figuras. [Documentação](https://plotly.com/python/plotly-express/)

# %%
# importar os pacotes necessarios
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %matplotlib inline

# %%
# importar o arquivo listings.csv para um DataFrame
df = pd.read_csv("http://data.insideairbnb.com/canada/bc/vancouver/2021-02-09/visualisations/listings.csv")

# %% [markdown]
# ## Análise dos Dados
#
#
# Após a importação do arquivo `listings.csv` que contem o conjunto de  dados que foram analisados, foi realizado a análise dos dados que tem por objetivo criar uma consciência situacional inicial e permitir um entendimento de como os dados estão estruturados no _dataFrame_ através da descrição de cada variável e o valor que ela representa.

# %% [markdown]
# **Dicionário das variáveis**
#
# * `id` - número de id gerado para identificar o imóvel
# * `name` - nome da propriedade anunciada
# * `host_id` - número de id do proprietário (anfitrião) da propriedade
# * `host_name` - Nome do anfitrião
# * `neighbourhood_group` - esta coluna não contém nenhum valor válido
# * `neighbourhood` - nome do bairro
# * `latitude` - coordenada da latitude da propriedade
# * `longitude` - coordenada da longitude da propriedade
# * `room_type` - informa o tipo de quarto que é oferecido
# * `price` - preço para alugar o imóvel
# * `minimum_nights` - quantidade mínima de noites para reservar
# * `number_of_reviews` - número de reviews que a propriedade possui
# * `last_review` - data do último review
# * `reviews_per_month` - quantidade de reviews por mês
# * `calculated_host_listings_count` - quantidade de imóveis do mesmo anfitrião
# * `availability_365` - número de dias de disponibilidade dentro de 365 dias
#
# Antes de iniciar qualquer análise, vamos verificar a cara do nosso *dataset*, analisando as 5 primeiras entradas.

# %%
# mostrar as 5 primeiras entradas do dataset
df.head()
# Out:
#       id  ... availability_365
# 0  10080  ...              345
# 1  13358  ...               70
# 2  13490  ...              291
# 3  14267  ...                0
# 4  16254  ...              228
#
# [5 rows x 16 columns]

# %% [markdown]
# ### **Q1. Quantos atributos (variáveis) e quantas entradas o nosso conjunto de dados possui? Quais os tipos das variáveis?**
#
# Vamos prosseguir e identificar a quantidade de entradas que nosso conjunto de dados possui e ver os tipos de cada coluna.
#
# Este dataset que baixamos é a versão "resumida" do Airbnb. Na mesma página que baixamos o arquivo `listings.csv`. Há uma versão mais completa com 4340 entradas e 74 variáveis (`listings.csv.gz`).
#
# Segue abaixo os valores da quantidade das variáveis e entradas como também os tipos das variáveis.

# %%
# identificar o volume de dados do DataFrame
print("Entradas:\t {}".format(df.shape[0]))
print("Variáveis:\t {}\n".format(df.shape[1]))

# verificar os tipos das variáveis do dataset
print(df.dtypes)
# Out:
# Entradas:	 4340
# Variáveis:	 16
#
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %% [markdown]
# ### **Q2. Qual a porcentagem de valores ausentes no *dataset*?**
#
# A qualidade de um dataset está diretamente relacionada à quantidade de valores ausentes. É importante entender logo no início se esses valores nulos são significativos comparados ao total de entradas.
#
# É possível ver que a coluna `neighbourhood_group` possui 100% dos seus valores faltantes.
# As variáveis `reviews_per_month` e `last_review` possuem valores nulos em boa parte das linhas.
# A variável `host_name` têm uma porcetagem bem pequena de valores nulos.

# %%
# ordenar em ordem decrescente as variáveis por seus valores ausentes
(df.isnull().sum() / df.shape[0]).sort_values(ascending=False)
# Out:
# neighbourhood_group               1.00000
# reviews_per_month                 0.18341
# last_review                       0.18341
# host_name                         0.00023
# availability_365                  0.00000
# calculated_host_listings_count    0.00000
# number_of_reviews                 0.00000
# minimum_nights                    0.00000
# price                             0.00000
# room_type                         0.00000
# longitude                         0.00000
# latitude                          0.00000
# neighbourhood                     0.00000
# host_id                           0.00000
# name                              0.00000
# id                                0.00000
# dtype: float64

# %%
# exibindo em gráfico de pizza as váriaveis que contêm valores ausentes
(df.isnull().sum() / df.shape[0]).sort_values(ascending=False).plot(kind='pie');

# %% [markdown]
# ### **Q3. Qual o tipo de distribuição das variáveis?**
#
# Para identificar a distribuição das variáveis, irei plotar o histograma.

# %%
# plotar o histograma das variáveis numéricas
df.hist(bins=15, figsize=(15,10));

# %% [markdown]
# ### **Q4. Há *outliers* presentes?**
#
# Pela distribuição do histograma, é possível verificar indícios da presença de *outliers*. Olhe por exemplo as variáveis `price`, `minimum_nights` e `calculated_host_listings_count`.
#
# Os valores não seguem uma distruição, e distorcem toda a representação gráfica. Para confirmar, há duas maneiras rápidas que auxiliam a detecção de *outliers*. São elas:
#
# * Resumo estatístico por meio do método `describe()`
# * Plotar `boxplots` para a variável.

# %%
# ver o resumo estatístico das variáveis numéricas
df[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
    'calculated_host_listings_count', 'availability_365']].describe()
# Out:
#              price  ...  availability_365
# count  4340.000000  ...       4340.000000
# mean    147.032719  ...        136.320737
# std     150.496886  ...        130.414382
# min      19.000000  ...          0.000000
# 25%      80.000000  ...          0.000000
# 50%     110.000000  ...         90.000000
# 75%     166.000000  ...        252.000000
# max    3250.000000  ...        365.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# Olhando o resumo estatístico acima, podemos confirmar algumas hipóteses como:
#
# * A variável `price` possui 75% do valor abaixo de 166, porém seu valor máximo é 3250.
# * A quantidade mínima de noites (`minimum_nights`) está acima de 365 dias no ano.
#
# #### Boxplot para minimum_nights

# %%
# minimum_nights
df.minimum_nights.plot(kind='box', vert=False, figsize=(15, 3))
plt.show()

# ver quantidade de valores acima de 30 dias para minimum_nights
print("minimum_nights: valores acima de 30:")
print("{} entradas".format(len(df[df.minimum_nights > 30])))
print("{:.4f}%".format((len(df[df.minimum_nights > 30]) / df.shape[0])*100))
# Out:
# minimum_nights: valores acima de 30:
# 335 entradas
# 7.7189%

# %% [markdown]
# #### Boxplot para price

# %%
# price
df.price.plot(kind='box', vert=False, figsize=(15, 3),)
plt.show()

# ver quantidade de valores acima de 1500 para price
print("\nprice: valores acima de 1500")
print("{} entradas".format(len(df[df.price > 1500])))
print("{:.4f}%".format((len(df[df.price > 1500]) / df.shape[0])*100))

df.price.plot(kind='box', vert=False, xlim=(0,1300), figsize=(15,3))
print("\n\n\nprice: valores abaixo de 1300")
# Out:
# price: valores acima de 1500
# 10 entradas
# 0.2304%
#
#
#
# price: valores abaixo de 1300

# %% [markdown]
# #### Histogramas sem *outliers*
#
# Já que identificamos *outliers* nas variáveis `price` e `minimum_nights`, vamos agora limpar o *DataFrame* delas e plotar novamente o histograma.

# %%
# remover os *outliers* em um novo DataFrame
df_clean = df.copy()
df_clean.drop(df_clean[df_clean.price > 1500].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.minimum_nights > 30].index, axis=0, inplace=True)

# remover `neighbourhood_group`, pois está vazio
df_clean.drop('neighbourhood_group', axis=1, inplace=True)

# plotar o histograma para as variáveis numéricas
df_clean.hist(bins=15, figsize=(15,10));

# %% [markdown]
# ### **Q5. Qual a correlação existente entre as variáveis**
#
# Correlação significa que existe uma relação entre duas coisas. No nosso contexto, estamos buscando relação ou semelhança entre duas variáveis.
#
# Essa relação pode ser medida, e é função do coeficiente de correlação estabelecer qual a intensidade dela. Para identificar as correlações existentes entre as variáveis de interesse, vou:
#
# * Criar uma matriz de correlação
# * Gerar um *heatmap* a partir dessa matriz, usando a biblioteca `seaborn`

# %%
# criar uma matriz de correlação
corr = df_clean[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
    'calculated_host_listings_count', 'availability_365']].corr()

# mostrar a matriz de correlação
display(corr)
# Out:
#                                    price  ...  availability_365
# price                           1.000000  ...          0.033508
# minimum_nights                 -0.112704  ...          0.219770
# number_of_reviews              -0.070643  ...          0.042784
# reviews_per_month              -0.091630  ...          0.023637
# calculated_host_listings_count -0.100119  ...          0.048544
# availability_365                0.033508  ...          1.000000
#
# [6 rows x 6 columns]

# %%
# plotar um heatmap a partir das correlações
sns.heatmap(corr, cmap='RdBu', fmt='.2f', square=True, linecolor='white', annot=True);

# %% [markdown]
# ### **Q6. Qual a média dos preços de aluguel?**
#
# * Lembrando que os valores listados estão representados pela moeda corrente do país. Então os valores dos preços correspondem ao valor do **Dólar Canadense C$**, em que no momento dessa análise **o valor de 1 Dólar é igual a 4.49 Reais**.
#
# A média dos preços de alugueis é de 143.42521260630315, ou seja **C$ 143 dólares canadenses**.
#
# Em Real o valor é equivalente a 643.9792046023011, ou seja **R$ 643.98 reais**.

# %%
# mostrar a média dos preços de aluguel
media = df_clean['price'].mean()

print("Média: ", media)

df_clean[['price']].describe()
# Out:
# Média:  143.42521260630315
#              price
# count  3998.000000
# mean    143.425213
# std     115.151892
# min      19.000000
# 25%      80.000000
# 50%     110.000000
# 75%     168.000000
# max    1145.000000

# %%
# criar uma função que converte Dolar Canadense em Real
def conversormoeda(cotacaodolar, real):
  return cotacaodolar * real

# %%
# mostrar o valor da media dos preços em reais - (dólar = 4.49)
cotacaodolar= 4.49
print("Em Reais: ", conversormoeda(cotacaodolar, media))
# Out:
# Em Reais:  643.9792046023011

# %% [markdown]
# ### **Q7. Qual o tipo de imóvel mais alugado no Airbnb?**
#
# A coluna da variável `room_type` indica o tipo de locação que está anunciada no Airbnb. Se você já alugou no site, sabe que existem opções de apartamentos/casas inteiras, apenas o aluguel de um quarto ou mesmo dividir o quarto com outras pessoas.
#
# Vamos contar a quantidade de ocorrências de cada tipo de aluguel, usando o método `value_counts()`.
#
# Percebe-se que apartamentos/casas inteiras é a opção que contem maior numero, representando 76% dos imóveis disponíveis para aluguel, em seguida vem a opção de quarto privado que representa 23% do total, e o restante é ocupado pelas demais opções.

# %%
# mostrar a quantidade de cada tipo de imóvel disponível
df_clean.room_type.value_counts()
# Out:
# Entire home/apt    3042
# Private room        939
# Shared room          13
# Hotel room            4
# Name: room_type, dtype: int64

# %%
# mostrar a porcentagem de cada tipo de imóvel disponível
df_clean.room_type.value_counts() / df_clean.shape[0]
# Out:
# Entire home/apt    0.760880
# Private room       0.234867
# Shared room        0.003252
# Hotel room         0.001001
# Name: room_type, dtype: float64

# %%
# mostrar a porcentagem de cada tipo de imóvel disponível em gráfico de barras
(df_clean.room_type.value_counts() / df_clean.shape[0]).plot(kind='bar');

# %% [markdown]
# ### **Q8. Qual é a média do mínimo de noites para aluguel (minimum_nights)?**
#
# É possível notar que a média do mínimo de noites é de (12.476488) 12 noites que é consideralvente alto e 75% equivalem a 30 que é o valor máximo de noites.

# %%
# ver a média da coluna `minimum_nights``
df_clean.minimum_nights.mean()
# Out:
# 12.476488244122061

# %%
# ver os valores (media, máximo, mínimo ...) da coluna `minimum_nights``
df_clean[['minimum_nights']].describe()
# Out:
#        minimum_nights
# count     3998.000000
# mean        12.476488
# std         13.197460
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%         30.000000
# max         30.000000

# %% [markdown]
# ### **Q9. Qual a localidade mais cara de Vancouver?**
#
# Uma maneira de se verificar uma variável em função da outra é usando `groupby()`. No caso, queremos comparar os bairros (*neighbourhoods*) a partir do preço de locação.
#
# É possível observar que o bairro de **Kitsilano** possui o preço mais caro como também esta entre os que possui a maior quantidade de imóveis. O bairro **Downtown** é o que contem mais imóveis disponíveis para aluguel.

# %%
# ver preços por bairros, na média
df_clean.groupby(['neighbourhood']).price.mean().sort_values(ascending=False)[:10]
# Out:
# neighbourhood
# Kitsilano            195.646018
# West Point Grey      175.145161
# Downtown             154.434739
# Downtown Eastside    153.064039
# Dunbar Southlands    152.347826
# Fairview             146.716667
# South Cambie         145.580000
# Riley Park           144.288462
# Arbutus Ridge        143.372881
# Mount Pleasant       140.130081
# Name: price, dtype: float64

# %%
# ver quantidade de imóveis de alguns bairros
print("Kitsilano:")
print(df_clean[df_clean.neighbourhood == "Kitsilano"].shape)
print("West Point Grey:")
print(df_clean[df_clean.neighbourhood == "West Point Grey"].shape)
print("Downtown:")
print(df_clean[df_clean.neighbourhood == "Downtown"].shape)
print("Riley Park:")
print(df_clean[df_clean.neighbourhood == "Riley Park"].shape)
# Out:
# Kitsilano:
# (339, 15)
# West Point Grey:
# (62, 15)
# Downtown:
# (996, 15)
# Riley Park:
# (208, 15)

# %% [markdown]
# Como são fornecidas as Latitudes e Longitudes para os imóveis, é possível plotar cada ponto. Para isso, considera-se `x=longitude` e `y=latitude`.

# %%
# plotar os imóveis pela latitude-longitude
df_clean.plot(kind="scatter", x='longitude', y='latitude', alpha=0.4, c=df_clean['price'], s=8,
              cmap=plt.get_cmap('jet'), figsize=(12,8));

# %% [markdown]
# Apartir das coordenadas Latitudes e Longitudes dos imóveis, tambem é possível mostrar uma mapa mais elaborado e melhor visualmente em que é possível navegar e visualizar dados importantes referentes ao imóvel como preço e descrição.

# %%
# Exibindo mapa detalhado com navegação
data_mapa = df[['name', 'latitude', 'longitude', 'price']]
#print(data_mapa.head())
mapa = px.scatter_mapbox(data_mapa, lat='latitude' , lon='longitude' , hover_name='name',
                hover_data=['price'], color_discrete_sequence=['fuchsia'],
               zoom=11, height=300)

mapa.update_layout(mapbox_style="open-street-map")
mapa.update_layout(height=600, margin={'r':0, 't':0, 'l':0, 'b':0})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e50d8860-0aac-4ac0-8d87-7680eb9f83d2" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e50d8860-0aac-4ac0-8d87-7680eb9f83d2")) {
#                     Plotly.newPlot(
#                         'e50d8860-0aac-4ac0-8d87-7680eb9f83d2',
# ...

# %% [markdown]
# ## Conclusões

# %% [markdown]
# Foi feita apenas uma análise superficial na base de dados do Airbnb, porém já se percebeu que existem *outliers* em algumas das variáveis.
#
# Também se notou que em algumas localidades há poucos imóveis disponíveis, o que pode distorcer as informações estatísticas de alguns atributos.
#
# Por fim, lembra-se que este *dataset* é uma versão resumida, ideal apenas para uma abordagem inicial. Recomenda-se que seja usado, em uma próxima análise exploratória, o conjunto de dados completos, com 74 atributos disponíveis.
#
# A partir desta análise, conclui-se que a utilização do Google Colab juntamente com as bibliotecas Python utilizadas é possível extrair dados estatísticos e avaliá-los de forma a compreender detalhes importantes sob determinado conjunto de dados, que nesse caso de estudo, foi analisado as listagens dos imóveis disponíveis para hospedagens na cidade de Vancouver no portal do Airbnb.

# %% [markdown]
# #### Links de Referências:

# %% [markdown]
# https://cursosnocanada.com.br/cidades/vancouver/
#
# http://www.canadaturismo.com.br/british-columbia.aspx
#
# https://www.projetocanada.com/turismo-viagem-canada/turismo-viagem-vancouver/
